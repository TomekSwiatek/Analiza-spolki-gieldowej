# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
"""
#do wykorzystania
def rule(x, y):
    if x == 'high' and y > 10:
         return 1
    else:
         return 0
df = pd.DataFrame({ 'c1':[ 'high' ,'high', 'low', 'low'], 'c2': [0, 23, 17, 4]})
df['new'] = df.apply(lambda x: rule(x['c1'], x['c2']), axis =  1)
df.head()
"""
# Out:
# "\n#do wykorzystania\ndef rule(x, y):\n    if x == 'high' and y > 10:\n         return 1\n    else:\n         return 0\ndf = pd.DataFrame({ 'c1':[ 'high' ,'high', 'low', 'low'], 'c2': [0, 23, 17, 4]})\ndf['new'] = df.apply(lambda x: rule(x['c1'], x['c2']), axis =  1)\ndf.head()\n"

# %%
plik = pd.ExcelFile('Livechat.xlsx') #wczytanie pliku .xls
df_temp = plik.parse() #zamiana tabeli excel na ramkę danych
df_temp
# Out:
#            Spółka  w tys. PLN  Przychody ze sprzedaży  \
# 0  LVC (LIVECHAT)        2011                     NaN
# 1  LVC (LIVECHAT)        2012                  5480.0
# 2  LVC (LIVECHAT)        2013                 11186.0
# 3  LVC (LIVECHAT)        2014                 18941.0
# 4  LVC (LIVECHAT)        2015                 33044.0
# 5  LVC (LIVECHAT)        2016                 53033.0
# 6  LVC (LIVECHAT)        2017                 76254.0
# 7  LVC (LIVECHAT)        2018                 89426.0
# 8  LVC (LIVECHAT)        2019                109299.0
# 9  LVC (LIVECHAT)        2020                124277.0
#
#    Techniczny koszt wytworzenia produkcji sprzedanej  Koszty sprzedaży  \
# 0                                                NaN               NaN
# 1                                              613.0             285.0
# 2                                             1732.0             762.0
# 3                                             2966.0            1761.0
# 4                                             5080.0            2636.0
# 5                                             8600.0            5656.0
# 6                                            11749.0            6859.0
# 7                                            14350.0            7193.0
# 8                                            17939.0           10465.0
# 9                                            18532.0           16610.0
#
#    Koszty ogólnego zarządu  Zysk ze sprzedaży  Pozostałe przychody operacyjne  \
# 0                      NaN                NaN                             NaN
# 1                   1090.0             3492.0                             5.0
# 2                    935.0             7757.0                             1.0
# 3                   2373.0            11841.0                           231.0
# 4                   2049.0            23279.0                            13.0
# 5                   3839.0            34938.0                            13.0
# 6                   4315.0            53331.0                            19.0
# 7                   6533.0            61350.0                            19.0
# 8                  10113.0            70782.0                            14.0
# 9                  12092.0            77043.0                            14.0
#
#    Pozostałe koszty operacyjne  Zysk operacyjny (EBIT)  ...  \
# 0                          NaN                     NaN  ...
# 1                        350.0                  3147.0  ...
# 2                        670.0                  7088.0  ...
# 3                          9.0                 12063.0  ...
# 4                         98.0                 23194.0  ...
# 5                          2.0                 34949.0  ...
# 6                          1.0                 53349.0  ...
# 7                          7.0                 61362.0  ...
# 8                         20.0                 70776.0  ...
# 9                         22.0                 77035.0  ...
#
#    Przepływy pieniężne z działalności operacyjnej  Amortyzacja  \
# 0                                             NaN          NaN
# 1                                          2342.0        119.0
# 2                                          6162.0        213.0
# 3                                         11140.0        551.0
# 4                                         17840.0        836.0
# 5                                         28480.0       1210.0
# 6                                         43205.0       1693.0
# 7                                         48178.0       1878.0
# 8                                         61189.0       3750.0
# 9                                         66231.0       5245.0
#
#    Przepływy pieniężne z działalności inwestycyjnej  \
# 0                                               NaN
# 1                                            -300.0
# 2                                           -5025.0
# 3                                            1732.0
# 4                                           -1577.0
# 5                                           -2145.0
# 6                                           -3859.0
# 7                                           -5156.0
# 8                                          -10546.0
# 9                                          -11059.0
#
#    CAPEX (niematerialne i rzeczowe)  \
# 0                               NaN
# 1                             300.0
# 2                            1425.0
# 3                            1961.0
# 4                            1685.0
# 5                            2145.0
# 6                            3978.0
# 7                            5287.0
# 8                           10708.0
# 9                           11153.0
#
#    Przepływy pieniężne z działalności finansowej  Emisja akcji  Dywidenda  \
# 0                                            NaN           NaN        NaN
# 1                                         -431.0          15.0        0.0
# 2                                        -1458.0           0.0     1459.0
# 3                                        -6000.0           0.0     6000.0
# 4                                        -9527.0           0.0     9527.0
# 5                                       -18283.0           0.0    18283.0
# 6                                       -27810.0           0.0    27810.0
# 7                                       -47638.0           0.0    47638.0
# 8                                       -48153.0           0.0    48153.0
# 9                                       -50213.0           0.0    50213.0
#
#    Temp6  Temp7  Przepływy pieniężne razem
# 0    NaN    NaN                        NaN
# 1    NaN    NaN                     1611.0
# 2    NaN    NaN                     -321.0
# 3    NaN    NaN                     6872.0
# 4    NaN    NaN                     6736.0
# 5    NaN    NaN                     8052.0
# 6    NaN    NaN                    11536.0
# 7    NaN    NaN                    -4616.0
# 8    NaN    NaN                     2490.0
# 9    NaN    NaN                     4959.0
#
# [10 rows x 67 columns]

# %%
df_temp=df_temp.drop(columns=['Temp1','Temp2','Temp3','Temp4','Temp5','Temp6','Temp7'], axis=1)#usunięcie niepotrzebnych kolumn
df=df_temp.drop(0, axis=0)
df
# Out:
#            Spółka  w tys. PLN  Przychody ze sprzedaży  \
# 1  LVC (LIVECHAT)        2012                  5480.0
# 2  LVC (LIVECHAT)        2013                 11186.0
# 3  LVC (LIVECHAT)        2014                 18941.0
# 4  LVC (LIVECHAT)        2015                 33044.0
# 5  LVC (LIVECHAT)        2016                 53033.0
# 6  LVC (LIVECHAT)        2017                 76254.0
# 7  LVC (LIVECHAT)        2018                 89426.0
# 8  LVC (LIVECHAT)        2019                109299.0
# 9  LVC (LIVECHAT)        2020                124277.0
#
#    Techniczny koszt wytworzenia produkcji sprzedanej  Koszty sprzedaży  \
# 1                                              613.0             285.0
# 2                                             1732.0             762.0
# 3                                             2966.0            1761.0
# 4                                             5080.0            2636.0
# 5                                             8600.0            5656.0
# 6                                            11749.0            6859.0
# 7                                            14350.0            7193.0
# 8                                            17939.0           10465.0
# 9                                            18532.0           16610.0
#
#    Koszty ogólnego zarządu  Zysk ze sprzedaży  Pozostałe przychody operacyjne  \
# 1                   1090.0             3492.0                             5.0
# 2                    935.0             7757.0                             1.0
# 3                   2373.0            11841.0                           231.0
# 4                   2049.0            23279.0                            13.0
# 5                   3839.0            34938.0                            13.0
# 6                   4315.0            53331.0                            19.0
# 7                   6533.0            61350.0                            19.0
# 8                  10113.0            70782.0                            14.0
# 9                  12092.0            77043.0                            14.0
#
#    Pozostałe koszty operacyjne  Zysk operacyjny (EBIT)  ...  \
# 1                        350.0                  3147.0  ...
# 2                        670.0                  7088.0  ...
# 3                          9.0                 12063.0  ...
# 4                         98.0                 23194.0  ...
# 5                          2.0                 34949.0  ...
# 6                          1.0                 53349.0  ...
# 7                          7.0                 61362.0  ...
# 8                         20.0                 70776.0  ...
# 9                         22.0                 77035.0  ...
#
#    Rozliczenia międzyokresowe  Pasywa razem  \
# 1                           0          3508
# 2                           0          8264
# 3                           0         12912
# 4                           0         21288
# 5                           0         32076
# 6                           0         47533
# 7                           0         48644
# 8                           0         61521
# 9                           0         73755
#
#    Przepływy pieniężne z działalności operacyjnej  Amortyzacja  \
# 1                                          2342.0        119.0
# 2                                          6162.0        213.0
# 3                                         11140.0        551.0
# 4                                         17840.0        836.0
# 5                                         28480.0       1210.0
# 6                                         43205.0       1693.0
# 7                                         48178.0       1878.0
# 8                                         61189.0       3750.0
# 9                                         66231.0       5245.0
#
#    Przepływy pieniężne z działalności inwestycyjnej  \
# 1                                            -300.0
# 2                                           -5025.0
# 3                                            1732.0
# 4                                           -1577.0
# 5                                           -2145.0
# 6                                           -3859.0
# 7                                           -5156.0
# 8                                          -10546.0
# 9                                          -11059.0
#
#    CAPEX (niematerialne i rzeczowe)  \
# 1                             300.0
# 2                            1425.0
# 3                            1961.0
# 4                            1685.0
# 5                            2145.0
# 6                            3978.0
# 7                            5287.0
# 8                           10708.0
# 9                           11153.0
#
#    Przepływy pieniężne z działalności finansowej  Emisja akcji  Dywidenda  \
# 1                                         -431.0          15.0        0.0
# 2                                        -1458.0           0.0     1459.0
# 3                                        -6000.0           0.0     6000.0
# 4                                        -9527.0           0.0     9527.0
# 5                                       -18283.0           0.0    18283.0
# 6                                       -27810.0           0.0    27810.0
# 7                                       -47638.0           0.0    47638.0
# 8                                       -48153.0           0.0    48153.0
# 9                                       -50213.0           0.0    50213.0
#
#    Przepływy pieniężne razem
# 1                     1611.0
# 2                     -321.0
# 3                     6872.0
# 4                     6736.0
# 5                     8052.0
# 6                    11536.0
# 7                    -4616.0
# 8                     2490.0
# 9                     4959.0
#
# [9 rows x 60 columns]

# %%
df.Spółka.unique()
# Out:
# array(['LVC (LIVECHAT)'], dtype=object)

# %%
df.shape
# Out:
# (9, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 1 to 9
# Data columns (total 60 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Spółka                                              9 non-null      object
#  1   w tys. PLN                                          9 non-null      int64
#  2   Przychody ze sprzedaży                              9 non-null      float64
#  3   Techniczny koszt wytworzenia produkcji sprzedanej   9 non-null      float64
#  4   Koszty sprzedaży                                    9 non-null      float64
#  5   Koszty ogólnego zarządu                             9 non-null      float64
#  6   Zysk ze sprzedaży                                   9 non-null      float64
#  7   Pozostałe przychody operacyjne                      9 non-null      float64
#  8   Pozostałe koszty operacyjne                         9 non-null      float64
#  9   Zysk operacyjny (EBIT)                              9 non-null      float64
#  10  Przychody finansowe                                 9 non-null      float64
#  11  Koszty finansowe                                    9 non-null      float64
#  12  Pozostałe przychody (koszty)                        9 non-null      float64
#  13  Zysk z działalności gospodarczej                    9 non-null      float64
#  14  Wynik zdarzeń nadzwyczajnych                        9 non-null      float64
#  15  Zysk przed opodatkowaniem                           9 non-null      float64
#  16  Zysk (strata) netto z działalności zaniechanej      9 non-null      float64
#  17  Zysk netto                                          9 non-null      float64
#  18  Zysk netto akcjonariuszy jednostki dominującej      9 non-null      float64
#  19  Aktywa trwałe                                       9 non-null      int64
#  20  Wartości niematerialne i prawne                     9 non-null      int64
#  21  Rzeczowe składniki majątku trwałego                 9 non-null      int64
#  22  Należności długoterminowe                           9 non-null      int64
#  23  Inwestycje długoterminowe                           9 non-null      int64
#  24  Pozostałe aktywa trwałe                             9 non-null      int64
#  25  Aktywa obrotowe                                     9 non-null      int64
#  26  Zapasy                                              9 non-null      int64
#  27  Należności krótkoterminowe                          9 non-null      int64
#  28  Inwestycje krótkoterminowe                          9 non-null      int64
#  29  Środki pieniężne i inne aktywa pieniężne            9 non-null      int64
#  30  Pozostałe aktywa obrotowe                           9 non-null      int64
#  31  Aktywa trwałe przeznaczone do sprzedaży             9 non-null      int64
#  32  Aktywa razem                                        9 non-null      int64
#  33  Kapitał własny akcjonariuszy jednostki dominującej  9 non-null      int64
#  34  Kapitał (fundusz) podstawowy                        9 non-null      int64
#  35  Udziały (akcje) własne                              9 non-null      int64
#  36  Kapitał (fundusz) zapasowy                          9 non-null      int64
#  37  Udziały niekontrolujące                             9 non-null      int64
#  38  Zobowiązania długoterminowe                         9 non-null      int64
#  39  Z tytułu dostaw i usług                             9 non-null      int64
#  40  Kredyty i pożyczki                                  9 non-null      int64
#  41  Z tytułu emisji dłużnych papierów wartościowych     9 non-null      int64
#  42  Zobowiązania z tytułu leasingu finansowego          9 non-null      int64
#  43  Inne zobowiązania długoterminowe                    9 non-null      int64
#  44  Zobowiązania krótkoterminowe                        9 non-null      int64
#  45  Z tytułu dostaw i usług.1                           9 non-null      int64
#  46  Kredyty i pożyczki.1                                9 non-null      int64
#  47  Z tytułu emisji dłużnych papierów wartościowych.1   9 non-null      int64
#  48  Zobowiązania z tytułu leasingu finansowego.1        9 non-null      int64
#  49  Inne zobowiązania krótkoterminowe                   9 non-null      int64
#  50  Rozliczenia międzyokresowe                          9 non-null      int64
#  51  Pasywa razem                                        9 non-null      int64
#  52  Przepływy pieniężne z działalności operacyjnej      9 non-null      float64
#  53  Amortyzacja                                         9 non-null      float64
#  54  Przepływy pieniężne z działalności inwestycyjnej    9 non-null      float64
#  55  CAPEX (niematerialne i rzeczowe)                    9 non-null      float64
#  56  Przepływy pieniężne z działalności finansowej       9 non-null      float64
#  57  Emisja akcji                                        9 non-null      float64
#  58  Dywidenda                                           9 non-null      float64
#  59  Przepływy pieniężne razem                           9 non-null      float64
# dtypes: float64(25), int64(34), object(1)
# memory usage: 4.3+ KB

# %%
df.describe()
# Out:
#         w tys. PLN  Przychody ze sprzedaży  \
# count     9.000000                9.000000
# mean   2016.000000            57882.222222
# std       2.738613            43971.417960
# min    2012.000000             5480.000000
# 25%    2014.000000            18941.000000
# 50%    2016.000000            53033.000000
# 75%    2018.000000            89426.000000
# max    2020.000000           124277.000000
#
#        Techniczny koszt wytworzenia produkcji sprzedanej  Koszty sprzedaży  \
# count                                           9.000000           9.00000
# mean                                         9062.333333        5803.00000
# std                                          6910.231780        5289.39973
# min                                           613.000000         285.00000
# 25%                                          2966.000000        1761.00000
# 50%                                          8600.000000        5656.00000
# 75%                                         14350.000000        7193.00000
# max                                         18532.000000       16610.00000
#
#        Koszty ogólnego zarządu  Zysk ze sprzedaży  \
# count                 9.000000           9.000000
# mean               4815.444444       38201.444444
# std                3995.650389       28272.624335
# min                 935.000000        3492.000000
# 25%                2049.000000       11841.000000
# 50%                3839.000000       34938.000000
# 75%                6533.000000       61350.000000
# max               12092.000000       77043.000000
#
#        Pozostałe przychody operacyjne  Pozostałe koszty operacyjne  \
# count                        9.000000                     9.000000
# mean                        36.555556                   131.000000
# std                         73.154137                   231.185532
# min                          1.000000                     1.000000
# 25%                         13.000000                     7.000000
# 50%                         14.000000                    20.000000
# 75%                         19.000000                    98.000000
# max                        231.000000                   670.000000
#
#        Zysk operacyjny (EBIT)  Przychody finansowe  ...  \
# count                9.000000             9.000000  ...
# mean             38107.000000           112.777778  ...
# std              28396.317464            62.543540  ...
# min               3147.000000             4.000000  ...
# 25%              12063.000000            60.000000  ...
# 50%              34949.000000           125.000000  ...
# 75%              61362.000000           144.000000  ...
# max              77035.000000           210.000000  ...
#
#        Rozliczenia międzyokresowe  Pasywa razem  \
# count                         9.0      9.000000
# mean                          0.0  34389.000000
# std                           0.0  24839.979433
# min                           0.0   3508.000000
# 25%                           0.0  12912.000000
# 50%                           0.0  32076.000000
# 75%                           0.0  48644.000000
# max                           0.0  73755.000000
#
#        Przepływy pieniężne z działalności operacyjnej  Amortyzacja  \
# count                                        9.000000     9.000000
# mean                                     31640.777778  1721.666667
# std                                      23992.478596  1725.346342
# min                                       2342.000000   119.000000
# 25%                                      11140.000000   551.000000
# 50%                                      28480.000000  1210.000000
# 75%                                      48178.000000  1878.000000
# max                                      66231.000000  5245.000000
#
#        Przepływy pieniężne z działalności inwestycyjnej  \
# count                                          9.000000
# mean                                       -4215.000000
# std                                         4337.744114
# min                                       -11059.000000
# 25%                                        -5156.000000
# 50%                                        -3859.000000
# 75%                                        -1577.000000
# max                                         1732.000000
#
#        CAPEX (niematerialne i rzeczowe)  \
# count                          9.000000
# mean                        4293.555556
# std                         4036.123577
# min                          300.000000
# 25%                         1685.000000
# 50%                         2145.000000
# 75%                         5287.000000
# max                        11153.000000
#
#        Przepływy pieniężne z działalności finansowej  Emisja akcji  \
# count                                       9.000000      9.000000
# mean                                   -23279.222222      1.666667
# std                                     20823.290985      5.000000
# min                                    -50213.000000      0.000000
# 25%                                    -47638.000000      0.000000
# 50%                                    -18283.000000      0.000000
# 75%                                     -6000.000000      0.000000
# max                                      -431.000000     15.000000
#
#           Dywidenda  Przepływy pieniężne razem
# count      9.000000                   9.000000
# mean   23231.444444                4146.555556
# std    20882.685179                4880.629727
# min        0.000000               -4616.000000
# 25%     6000.000000                1611.000000
# 50%    18283.000000                4959.000000
# 75%    47638.000000                6872.000000
# max    50213.000000               11536.000000
#
# [8 rows x 59 columns]

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['w tys. PLN'],df['Przychody ze sprzedaży'], color = 'lightgray', alpha=0.5, label = 'Przychody w tys. PLN')
plt.bar(df['w tys. PLN'],df['Zysk ze sprzedaży'], color = 'darkgray', alpha=0.5, label = 'Zysk ze sprzedaży w tys. PLN')
plt.bar(df['w tys. PLN'],df['Zysk netto'], color = 'gray', alpha=0.5, label = 'Zysk netto w tys. PLN')

plt.xticks(df['w tys. PLN'])
 
plt.legend(frameon=False)
plt.xlabel('Lata')
plt.ylabel('Wartość')
plt.title('Przychody spółki');

# %% [markdown]
# # Wskaźniki

# %%
#Rentowność
df['ROE %'] = round((df['Zysk netto']/df['Kapitał własny akcjonariuszy jednostki dominującej'])*100,2) #najlepsze >20%
df['ROA %'] = round((df['Zysk netto']/df['Aktywa razem'])*100,2) #najlepsze >10%
df['ROS %'] = round((df['Zysk ze sprzedaży']/df['Przychody ze sprzedaży'])*100,2) #najlepsze >10%
df['Rentowność operacyjna %'] = round((df['Zysk operacyjny (EBIT)']/df['Przychody ze sprzedaży'])*100,2) #najlepsza >10%
df['Rentowność zysku netto %'] = round((df['Zysk netto']/df['Przychody ze sprzedaży'])*100,2) #najlepsza >10%

# %%
#Płynność
df['Płynność bieżąca'] = round((df['Aktywa obrotowe']/df['Zobowiązania krótkoterminowe']),2) #najlepsza >2
df['Płynność gotówkowa %'] = round((df['Środki pieniężne i inne aktywa pieniężne']/df['Zobowiązania krótkoterminowe'])*100,2) #najlepsza >20%
df['Kapital obrotowy'] = round((df['Aktywa obrotowe']-df['Zobowiązania krótkoterminowe']),0) #najlepszy >0

# %%
#Aktywności
df['Cykl inkasa należności'] = round((df['Należności krótkoterminowe']*365/df['Przychody ze sprzedaży']),0) #
df['Rotacja zapasów'] = round((df['Zapasy']*365/df['Przychody ze sprzedaży']),0) #
df['Cykl spłaty zobowiązań'] = round((df['Zobowiązania krótkoterminowe']*365/df['Przychody ze sprzedaży']),0) #
df['Cykl konwersji gotówki'] = round((df['Cykl inkasa należności']+df['Rotacja zapasów']-df['Cykl spłaty zobowiązań']),0) #najlepszy <0

# %%
#Zadłużenie
df['Zadłużenie długoterminowe kapitału własnego'] = round((df['Zobowiązania długoterminowe']/df['Kapitał własny akcjonariuszy jednostki dominującej'])*100,2) #najlepsza <20%
df['Wskaźnik ogólnego zadłużenia'] = round(((df['Zobowiązania długoterminowe']+df['Zobowiązania krótkoterminowe'])/df['Aktywa razem'])*100,2) #najlepsza <67%

# %%
#Majątkowe
df['I stopień pokrycia'] = round((df['Kapitał własny akcjonariuszy jednostki dominującej']/df['Aktywa trwałe']),2) #najlepsza >0.6

# %%
#Przepływy pieniężne
def przepływ(typ):
        if typ > 0: return 1
        else: return 0
        
df['Przepływy pieniężne z działalności operacyjnej ocena']=0        
df['Przepływy pieniężne z działalności operacyjnej ocena']=df['Przepływy pieniężne z działalności operacyjnej'].apply(przepływ)#najlepsza >0

df['Przepływy pieniężne z działalności inwestycyjnej ocena']=0        
df['Przepływy pieniężne z działalności inwestycyjnej ocena']=df['Przepływy pieniężne z działalności inwestycyjnej'].apply(przepływ)#najlepsza <0

df['Przepływy pieniężne z działalności finansowej ocena']=0        
df['Przepływy pieniężne z działalności finansowej ocena']=df['Przepływy pieniężne z działalności finansowej'].apply(przepływ)#najlepsza <0

df['Przepływy pieniężne razem ocena']=0        
df['Przepływy pieniężne razem ocena']=df['Przepływy pieniężne razem'].apply(przepływ)#najlepsza >0

# %%
#Przepływy pieniężne opis

def przepływy(typ):
        if ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] > 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena'] > 0) & \
        (typ['Przepływy pieniężne z działalności finansowej ocena'] > 0)) : return 'I - (+++) rzadka sytuacja, potrzeba analizy sprawzd.'      
        elif ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] > 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena']) > 0 & \
        (typ['Przepływy pieniężne z działalności finansowej ocena']) == 0): return 'II - (++-) proces restrukturyzacji'    
        elif ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] > 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena']) == 0 & \
        (typ['Przepływy pieniężne z działalności finansowej ocena']) == 0): return 'III - (+--) stabilna spółka, najlepsza sytuacja'    
        elif ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] == 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena']) == 0 & \
        (typ['Przepływy pieniężne z działalności finansowej ocena']) == 0) : return 'IV - (---) bankrut'    
        elif ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] < 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena']) > 0 & \
        (typ['Przepływy pieniężne z działalności finansowej ocena']) > 0)  : return 'V - (-++) tymczasowe problemy'    
        elif ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] == 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena']) == 0 & \
        (typ['Przepływy pieniężne z działalności finansowej ocena']) > 0)  : return 'VI - (--+) start-up, wczesna faza dzialalności'    
        elif ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] == 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena']) > 0 & \
        (typ['Przepływy pieniężne z działalności finansowej ocena']) == 0)   : return 'VII - (-+-) prawdopodobny bankrut'    
        elif ((typ['Przepływy pieniężne z działalności operacyjnej ocena'] > 0) & \
        (typ['Przepływy pieniężne z działalności inwestycyjnej ocena']) == 0 & \
        (typ['Przepływy pieniężne z działalności finansowej ocena']) == 0)  : return 'VIII - (+-+) po fazie start-up'                                 
        else: return 'Błąd'

df['Przepływy pieniężne opis']='0'      
df['Przepływy pieniężne opis']=df.apply(przepływy, axis=1)

# %%
df['Przepływy pieniężne opis']
# Out:
# 1    III - (+--) stabilna spółka, najlepsza sytuacja
# 2    III - (+--) stabilna spółka, najlepsza sytuacja
# 3                 II - (++-) proces restrukturyzacji
# 4    III - (+--) stabilna spółka, najlepsza sytuacja
# 5    III - (+--) stabilna spółka, najlepsza sytuacja
# 6    III - (+--) stabilna spółka, najlepsza sytuacja
# 7    III - (+--) stabilna spółka, najlepsza sytuacja
# 8    III - (+--) stabilna spółka, najlepsza sytuacja
# 9    III - (+--) stabilna spółka, najlepsza sytuacja
# Name: Przepływy pieniężne opis, dtype: object

# %%
#df['Wartość księgowa'] = (df['Kapitał własny akcjonariuszy jednostki dominującej']-df['Kapitał własny akcjonariuszy jednostki dominującej'])
#df
#dodanie Wzrastanie przychodów ze sprzedaży
#dodanie Wzrastanie zysku netto
