# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Upload the file with the data of the analyzed stock

# %%
file = pd.ExcelFile('Livechat.xlsx') #load file .xls
#file = pd.ExcelFile('Eurotel.xlsx') #load file .xls
df_temp = file.parse( names = ['Company', 'Year', 'Revenue', 'Cost of production', 'Cost of sales', 'Management costs', 'Gross Profit',
                               'Other operating income', 'Other operating cost', 'Operating income (EBIT)', 'Financial income', 'Financial costs',
                               'Other income (costs)', 'Profit from business activities', 'Result of extraordinary events', 'Income before tax',
                               'Profit (loss) from discontinued operations', 'Net income', 'Net profit of the shareholders of the parent company',
                               'Temp1', 'Temp2', 'Fixed assets', 'Intangible assets', 'Temp3', 'Tangible fixed assets', 'Temp4', 'Long-Term liabilities',
                               'Long-Term investments', 'Other fixed assets', 'Current assets', 'Inventory', 'Short-Term Liabilities', 'Short-Term investments',
                               'Cash and equivalents', 'Other current assets', 'Fixed assets for sale', 'Total assets', 'Equity', 'Share capital', 'Own shares',
                               'Supplementary capital (fund)', 'Non-controlling share', 'Long term debt', 'For supplies and services (Long term debt)', 'Credits and loans (Long term debt)',
                               'Due to the issue of debt securities (Long term debt)', 'Finance lease liabilities (Long term debt)', 'Other long-term liabilities (Long term debt)',
                               'Short term debt', 'For supplies and services (Short term debt)', 'Credits and loans (Short term debt)', 'Due to the issue of debt securities (Short term debt)',
                               'Finance lease liabilities (Short term debt)', 'Other short-term liabilities (Short term debt)', 'Accruals', 'Total Liabilities', 'Temp5', 
                               'Operating cash flow', 'Amortization', 'Investing cash flow', 'CAPEX (intangible and tangible)', 'Finance cash flow', 
                               'Issue of shares', 'Dividend', 'Temp6', 'Temp7', 'Free cash flow', 'Dividend rate', 'Value of the dividend per share']) #convert excel table into data frame
df_temp
# Out:
#           Company  Year   Revenue  Cost of production  Cost of sales  \
# 0  LVC (LIVECHAT)  2011       NaN                 NaN            NaN
# 1  LVC (LIVECHAT)  2012    5480.0               613.0          285.0
# 2  LVC (LIVECHAT)  2013   11186.0              1732.0          762.0
# 3  LVC (LIVECHAT)  2014   18941.0              2966.0         1761.0
# 4  LVC (LIVECHAT)  2015   33044.0              5080.0         2636.0
# 5  LVC (LIVECHAT)  2016   53033.0              8600.0         5656.0
# 6  LVC (LIVECHAT)  2017   76254.0             11749.0         6859.0
# 7  LVC (LIVECHAT)  2018   89426.0             14350.0         7193.0
# 8  LVC (LIVECHAT)  2019  109299.0             17939.0        10465.0
# 9  LVC (LIVECHAT)  2020  124277.0             18532.0        16610.0
#
#    Management costs  Gross Profit  Other operating income  \
# 0               NaN           NaN                     NaN
# 1            1090.0        3492.0                     5.0
# 2             935.0        7757.0                     1.0
# 3            2373.0       11841.0                   231.0
# 4            2049.0       23279.0                    13.0
# 5            3839.0       34938.0                    13.0
# 6            4315.0       53331.0                    19.0
# 7            6533.0       61350.0                    19.0
# 8           10113.0       70782.0                    14.0
# 9           12092.0       77043.0                    14.0
#
#    Other operating cost  Operating income (EBIT)  ...  Investing cash flow  \
# 0                   NaN                      NaN  ...                  NaN
# 1                 350.0                   3147.0  ...               -300.0
# 2                 670.0                   7088.0  ...              -5025.0
# 3                   9.0                  12063.0  ...               1732.0
# 4                  98.0                  23194.0  ...              -1577.0
# 5                   2.0                  34949.0  ...              -2145.0
# 6                   1.0                  53349.0  ...              -3859.0
# 7                   7.0                  61362.0  ...              -5156.0
# 8                  20.0                  70776.0  ...             -10546.0
# 9                  22.0                  77035.0  ...             -11059.0
#
#    CAPEX (intangible and tangible)  Finance cash flow  Issue of shares  \
# 0                              NaN                NaN              NaN
# 1                            300.0             -431.0             15.0
# 2                           1425.0            -1458.0              0.0
# 3                           1961.0            -6000.0              0.0
# 4                           1685.0            -9527.0              0.0
# 5                           2145.0           -18283.0              0.0
# 6                           3978.0           -27810.0              0.0
# 7                           5287.0           -47638.0              0.0
# 8                          10708.0           -48153.0              0.0
# 9                          11153.0           -50213.0              0.0
#
#    Dividend  Temp6  Temp7  Free cash flow  Dividend rate  \
# 0       NaN    NaN    NaN             NaN            NaN
# 1       0.0    NaN    NaN          1611.0            NaN
# 2    1459.0    NaN    NaN          -321.0            NaN
# 3    6000.0    NaN    NaN          6872.0          0.021
# 4    9527.0    NaN    NaN          6736.0          0.024
# 5   18283.0    NaN    NaN          8052.0          0.023
# 6   27810.0    NaN    NaN         11536.0          0.025
# 7   47638.0    NaN    NaN         -4616.0          0.010
# 8   48153.0    NaN    NaN          2490.0          0.021
# 9   50213.0    NaN    NaN          4959.0          0.014
#
#    Value of the dividend per share
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                             0.37
# 4                             0.71
# 5                             1.08
# 6                             1.41
# 7                             1.77
# 8                             1.95
# 9                             2.48
#
# [10 rows x 69 columns]

# %% [markdown]
# ## Data modification

# %%
df_temp=df_temp.drop(columns=['Temp1','Temp2','Temp3','Temp4','Temp5',\
                              'Temp6','Temp7'], axis=1) # remove unnecessary columns
df=df_temp.drop(0, axis=0) #when required to delete results for 1 year 
#df=df_temp #when not required, no deletion of results for 1 year 

df['Dividend rate']=df['Dividend rate']*100 #converting values into percentages

# %% [markdown]
# ## Initial data analysis
# The values of all the attributes are expressed **in thous. PLN**.

# %%
df
# Out:
#           Company  Year   Revenue  Cost of production  Cost of sales  \
# 1  LVC (LIVECHAT)  2012    5480.0               613.0          285.0
# 2  LVC (LIVECHAT)  2013   11186.0              1732.0          762.0
# 3  LVC (LIVECHAT)  2014   18941.0              2966.0         1761.0
# 4  LVC (LIVECHAT)  2015   33044.0              5080.0         2636.0
# 5  LVC (LIVECHAT)  2016   53033.0              8600.0         5656.0
# 6  LVC (LIVECHAT)  2017   76254.0             11749.0         6859.0
# 7  LVC (LIVECHAT)  2018   89426.0             14350.0         7193.0
# 8  LVC (LIVECHAT)  2019  109299.0             17939.0        10465.0
# 9  LVC (LIVECHAT)  2020  124277.0             18532.0        16610.0
#
#    Management costs  Gross Profit  Other operating income  \
# 1            1090.0        3492.0                     5.0
# 2             935.0        7757.0                     1.0
# 3            2373.0       11841.0                   231.0
# 4            2049.0       23279.0                    13.0
# 5            3839.0       34938.0                    13.0
# 6            4315.0       53331.0                    19.0
# 7            6533.0       61350.0                    19.0
# 8           10113.0       70782.0                    14.0
# 9           12092.0       77043.0                    14.0
#
#    Other operating cost  Operating income (EBIT)  ...  Operating cash flow  \
# 1                 350.0                   3147.0  ...               2342.0
# 2                 670.0                   7088.0  ...               6162.0
# 3                   9.0                  12063.0  ...              11140.0
# 4                  98.0                  23194.0  ...              17840.0
# 5                   2.0                  34949.0  ...              28480.0
# 6                   1.0                  53349.0  ...              43205.0
# 7                   7.0                  61362.0  ...              48178.0
# 8                  20.0                  70776.0  ...              61189.0
# 9                  22.0                  77035.0  ...              66231.0
#
#    Amortization  Investing cash flow  CAPEX (intangible and tangible)  \
# 1         119.0               -300.0                            300.0
# 2         213.0              -5025.0                           1425.0
# 3         551.0               1732.0                           1961.0
# 4         836.0              -1577.0                           1685.0
# 5        1210.0              -2145.0                           2145.0
# 6        1693.0              -3859.0                           3978.0
# 7        1878.0              -5156.0                           5287.0
# 8        3750.0             -10546.0                          10708.0
# 9        5245.0             -11059.0                          11153.0
#
#    Finance cash flow  Issue of shares  Dividend  Free cash flow  \
# 1             -431.0             15.0       0.0          1611.0
# 2            -1458.0              0.0    1459.0          -321.0
# 3            -6000.0              0.0    6000.0          6872.0
# 4            -9527.0              0.0    9527.0          6736.0
# 5           -18283.0              0.0   18283.0          8052.0
# 6           -27810.0              0.0   27810.0         11536.0
# 7           -47638.0              0.0   47638.0         -4616.0
# 8           -48153.0              0.0   48153.0          2490.0
# 9           -50213.0              0.0   50213.0          4959.0
#
#    Dividend rate  Value of the dividend per share
# 1            NaN                              NaN
# 2            NaN                              NaN
# 3            2.1                             0.37
# 4            2.4                             0.71
# 5            2.3                             1.08
# 6            2.5                             1.41
# 7            1.0                             1.77
# 8            2.1                             1.95
# 9            1.4                             2.48
#
# [9 rows x 62 columns]

# %%
df[:][['Net income']]
# Out:
#    Net income
# 1      2396.0
# 2      5661.0
# 3      9700.0
# 4     18557.0
# 5     28073.0
# 6     42917.0
# 7     48305.0
# 8     57266.0
# 9     62095.0

# %%
print ('Company name:',df.Company.unique())
# Out:
# Company name: ['LVC (LIVECHAT)']

# %%
print ('Number of years:',df.shape[0],'\n')
print ('Number of attributes:',df.shape[1])
# Out:
# Number of years: 9
#
# Number of attributes: 62

# %%
#Attribute types 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 1 to 9
# Data columns (total 62 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Company                                                9 non-null      object
#  1   Year                                                   9 non-null      int64
#  2   Revenue                                                9 non-null      float64
#  3   Cost of production                                     9 non-null      float64
#  4   Cost of sales                                          9 non-null      float64
#  5   Management costs                                       9 non-null      float64
#  6   Gross Profit                                           9 non-null      float64
#  7   Other operating income                                 9 non-null      float64
#  8   Other operating cost                                   9 non-null      float64
#  9   Operating income (EBIT)                                9 non-null      float64
#  10  Financial income                                       9 non-null      float64
#  11  Financial costs                                        9 non-null      float64
#  12  Other income (costs)                                   9 non-null      float64
#  13  Profit from business activities                        9 non-null      float64
#  14  Result of extraordinary events                         9 non-null      float64
#  15  Income before tax                                      9 non-null      float64
#  16  Profit (loss) from discontinued operations             9 non-null      float64
#  17  Net income                                             9 non-null      float64
#  18  Net profit of the shareholders of the parent company   9 non-null      float64
#  19  Fixed assets                                           9 non-null      int64
#  20  Intangible assets                                      9 non-null      int64
#  21  Tangible fixed assets                                  9 non-null      int64
#  22  Long-Term liabilities                                  9 non-null      int64
#  23  Long-Term investments                                  9 non-null      int64
#  24  Other fixed assets                                     9 non-null      int64
#  25  Current assets                                         9 non-null      int64
#  26  Inventory                                              9 non-null      int64
#  27  Short-Term Liabilities                                 9 non-null      int64
#  28  Short-Term investments                                 9 non-null      int64
#  29  Cash and equivalents                                   9 non-null      int64
#  30  Other current assets                                   9 non-null      int64
#  31  Fixed assets for sale                                  9 non-null      int64
#  32  Total assets                                           9 non-null      int64
#  33  Equity                                                 9 non-null      int64
#  34  Share capital                                          9 non-null      int64
#  35  Own shares                                             9 non-null      int64
#  36  Supplementary capital (fund)                           9 non-null      int64
#  37  Non-controlling share                                  9 non-null      int64
#  38  Long term debt                                         9 non-null      int64
#  39  For supplies and services (Long term debt)             9 non-null      int64
#  40  Credits and loans (Long term debt)                     9 non-null      int64
#  41  Due to the issue of debt securities (Long term debt)   9 non-null      int64
#  42  Finance lease liabilities (Long term debt)             9 non-null      int64
#  43  Other long-term liabilities (Long term debt)           9 non-null      int64
#  44  Short term debt                                        9 non-null      int64
#  45  For supplies and services (Short term debt)            9 non-null      int64
#  46  Credits and loans (Short term debt)                    9 non-null      int64
#  47  Due to the issue of debt securities (Short term debt)  9 non-null      int64
#  48  Finance lease liabilities (Short term debt)            9 non-null      int64
#  49  Other short-term liabilities (Short term debt)         9 non-null      int64
#  50  Accruals                                               9 non-null      int64
#  51  Total Liabilities                                      9 non-null      int64
#  52  Operating cash flow                                    9 non-null      float64
#  53  Amortization                                           9 non-null      float64
#  54  Investing cash flow                                    9 non-null      float64
#  55  CAPEX (intangible and tangible)                        9 non-null      float64
#  56  Finance cash flow                                      9 non-null      float64
#  57  Issue of shares                                        9 non-null      float64
#  58  Dividend                                               9 non-null      float64
#  59  Free cash flow                                         9 non-null      float64
#  60  Dividend rate                                          7 non-null      float64
#  61  Value of the dividend per share                        7 non-null      float64
# dtypes: float64(27), int64(34), object(1)
# memory usage: 4.4+ KB

# %%
#Lack of data 
df.isnull().sum()
# Out:
# Company                            0
# Year                               0
# Revenue                            0
# Cost of production                 0
# Cost of sales                      0
#                                   ..
# Issue of shares                    0
# Dividend                           0
# Free cash flow                     0
# Dividend rate                      2
# Value of the dividend per share    2
# Length: 62, dtype: int64

# %%
df.notnull().sum()
# Out:
# Company                            9
# Year                               9
# Revenue                            9
# Cost of production                 9
# Cost of sales                      9
#                                   ..
# Issue of shares                    9
# Dividend                           9
# Free cash flow                     9
# Dividend rate                      7
# Value of the dividend per share    7
# Length: 62, dtype: int64

# %%
#Change NaN value to 0 
df.fillna(value=0, inplace=True)

# %%
#Checking the number of duplicates 
df.duplicated().sum()
# Out:
# 0

# %%
#Removal of duplicates 
if df.duplicated().sum()>0:
    df.drop_duplicates()

# %%
#Statistical indicators 
df.describe()
# Out:
#               Year        Revenue  Cost of production  Cost of sales  \
# count     9.000000       9.000000            9.000000        9.00000
# mean   2016.000000   57882.222222         9062.333333     5803.00000
# std       2.738613   43971.417960         6910.231780     5289.39973
# min    2012.000000    5480.000000          613.000000      285.00000
# 25%    2014.000000   18941.000000         2966.000000     1761.00000
# 50%    2016.000000   53033.000000         8600.000000     5656.00000
# 75%    2018.000000   89426.000000        14350.000000     7193.00000
# max    2020.000000  124277.000000        18532.000000    16610.00000
#
#        Management costs  Gross Profit  Other operating income  \
# count          9.000000      9.000000                9.000000
# mean        4815.444444  38201.444444               36.555556
# std         3995.650389  28272.624335               73.154137
# min          935.000000   3492.000000                1.000000
# 25%         2049.000000  11841.000000               13.000000
# 50%         3839.000000  34938.000000               14.000000
# 75%         6533.000000  61350.000000               19.000000
# max        12092.000000  77043.000000              231.000000
#
#        Other operating cost  Operating income (EBIT)  Financial income  ...  \
# count              9.000000                 9.000000          9.000000  ...
# mean             131.000000             38107.000000        112.777778  ...
# std              231.185532             28396.317464         62.543540  ...
# min                1.000000              3147.000000          4.000000  ...
# 25%                7.000000             12063.000000         60.000000  ...
# 50%               20.000000             34949.000000        125.000000  ...
# 75%               98.000000             61362.000000        144.000000  ...
# max              670.000000             77035.000000        210.000000  ...
#
#        Operating cash flow  Amortization  Investing cash flow  \
# count             9.000000      9.000000             9.000000
# mean          31640.777778   1721.666667         -4215.000000
# std           23992.478596   1725.346342          4337.744114
# min            2342.000000    119.000000        -11059.000000
# 25%           11140.000000    551.000000         -5156.000000
# 50%           28480.000000   1210.000000         -3859.000000
# 75%           48178.000000   1878.000000         -1577.000000
# max           66231.000000   5245.000000          1732.000000
#
#        CAPEX (intangible and tangible)  Finance cash flow  Issue of shares  \
# count                         9.000000           9.000000         9.000000
# mean                       4293.555556      -23279.222222         1.666667
# std                        4036.123577       20823.290985         5.000000
# min                         300.000000      -50213.000000         0.000000
# 25%                        1685.000000      -47638.000000         0.000000
# 50%                        2145.000000      -18283.000000         0.000000
# 75%                        5287.000000       -6000.000000         0.000000
# max                       11153.000000        -431.000000        15.000000
#
#            Dividend  Free cash flow  Dividend rate  \
# count      9.000000        9.000000       9.000000
# mean   23231.444444     4146.555556       1.533333
# std    20882.685179     4880.629727       0.994987
# min        0.000000    -4616.000000       0.000000
# 25%     6000.000000     1611.000000       1.000000
# 50%    18283.000000     4959.000000       2.100000
# 75%    47638.000000     6872.000000       2.300000
# max    50213.000000    11536.000000       2.500000
#
#        Value of the dividend per share
# count                         9.000000
# mean                          1.085556
# std                           0.885679
# min                           0.000000
# 25%                           0.370000
# 50%                           1.080000
# 75%                           1.770000
# max                           2.480000
#
# [8 rows x 61 columns]

# %%
df['Net income'].describe()
# Out:
# count        9.000000
# mean     30552.222222
# std      22841.339895
# min       2396.000000
# 25%       9700.000000
# 50%      28073.000000
# 75%      48305.000000
# max      62095.000000
# Name: Net income, dtype: float64

# %%
df[  df['Net income'] > df['Operating cash flow']  ]
# Out:
#           Company  Year  Revenue  Cost of production  Cost of sales  \
# 1  LVC (LIVECHAT)  2012   5480.0               613.0          285.0
# 4  LVC (LIVECHAT)  2015  33044.0              5080.0         2636.0
# 7  LVC (LIVECHAT)  2018  89426.0             14350.0         7193.0
#
#    Management costs  Gross Profit  Other operating income  \
# 1            1090.0        3492.0                     5.0
# 4            2049.0       23279.0                    13.0
# 7            6533.0       61350.0                    19.0
#
#    Other operating cost  Operating income (EBIT)  ...  Operating cash flow  \
# 1                 350.0                   3147.0  ...               2342.0
# 4                  98.0                  23194.0  ...              17840.0
# 7                   7.0                  61362.0  ...              48178.0
#
#    Amortization  Investing cash flow  CAPEX (intangible and tangible)  \
# 1         119.0               -300.0                            300.0
# 4         836.0              -1577.0                           1685.0
# 7        1878.0              -5156.0                           5287.0
#
#    Finance cash flow  Issue of shares  Dividend  Free cash flow  \
# 1             -431.0             15.0       0.0          1611.0
# 4            -9527.0              0.0    9527.0          6736.0
# 7           -47638.0              0.0   47638.0         -4616.0
#
#    Dividend rate  Value of the dividend per share
# 1            0.0                             0.00
# 4            2.4                             0.71
# 7            1.0                             1.77
#
# [3 rows x 62 columns]

# %% [markdown]
# ## Charts

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Year'],df['Revenue'], color = 'lightgray', alpha=0.5, label = 'Revenues in thous. PLN')
plt.bar(df['Year'],df['Gross Profit'], color = 'darkgray', alpha=0.5, label = 'Gross profit in thous. PLN')
plt.bar(df['Year'],df['Net income'], color = 'gray', alpha=0.5, label = 'Net income in thous. PLN')

plt.xticks(df['Year'])
 
plt.legend(frameon=False)
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Company results');

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Year', y='Revenue', 
                  data=df, 
                  color='black', 
                  label = 'Revenue')
ax = sns.lineplot(x='Year', y='Net income', 
                  data=df, 
                  color='blue', 
                  label = 'Net income')
ax = sns.lineplot(x='Year', y='Equity', 
                  data=df, 
                  color='slategrey', 
                  label = 'Equity')

ax = sns.lineplot(x='Year', y='Long term debt', 
                  data=df, 
                  color='firebrick', 
                  label = 'Long term debt')
ax = sns.lineplot(x='Year', y='Short term debt', 
                  data=df, 
                  color='lightcoral', 
                  label = 'Short term debt')

ax = sns.lineplot(x='Year', y='Operating cash flow', 
                  data=df, 
                  color='palegreen', 
                  label = 'Operating cash flow')
ax = sns.lineplot(x='Year', y='Investing cash flow', 
                  data=df, 
                  color='lime', 
                  label = 'Investing cash flow')
ax = sns.lineplot(x='Year', y='Finance cash flow', 
                  data=df, 
                  color='olive', 
                  label = 'Finance cash flow')
ax = sns.lineplot(x='Year', y='Free cash flow', 
                  data=df, 
                  color='green', 
                  label = 'Free cash flow')
                  
ax = sns.lineplot(x='Year', y='Dividend', 
                  data=df, 
                  color='purple', 
                  label = 'Dividend')
                  
ax.set_title('Basic financial values');
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend(frameon=False)

# %% [markdown]
# # Indicators

# %%
#Book value 
for i in range(2, df.Year.count()+1):
    #df.loc[1,'Change in book value %']=100
    df.loc[i,'Change in book value %']=round(((df.loc[i,'Equity']- \
                                         df.loc[i-1,'Equity']) \
                                         /df.loc[i-1,'Equity'])*100,0) #the best >0
#Increasing sales revenues
for i in range(2, df.Year.count()+1):
    #df.loc[1,'Change in sales revenues %']=100
    df.loc[i,'Change in revenues %']=round(((df.loc[i,'Revenue']- \
                                                   df.loc[i-1,'Revenue']) \
                                                   /df.loc[i-1,'Revenue'])*100,0) #the best >0

#Increasing net income
for i in range(2, df.Year.count()+1):
    #df.loc[1,'Change in net income %']=100
    df.loc[i,'Change in net income %']=round(((df.loc[i,'Net income']-df.loc[i-1,'Net income'])\
                                              /df.loc[i-1,'Net income'])*100,0) #the best >0

# %%
#Profitability 
df['ROE %'] = round((df['Net income']/df['Equity'])*100,2) #the best >20%
df['ROA %'] = round((df['Net income']/df['Total assets'])*100,2) #the best >10%
df['ROS %'] = round((df['Gross Profit']/df['Revenue'])*100,2) #the best >10%
df['Operating margin %'] = round((df['Operating income (EBIT)']/df['Revenue'])*100,2) #the best >10%
df['Net margin %'] = round((df['Net income']/df['Revenue'])*100,2) #the best >10%

# %%
#Liquidity 
df['Current ratio'] = round((df['Current assets']/df['Short term debt']),2) #the best >2
df['Cash ratio %'] = round((df['Cash and equivalents']/df['Short term debt'])*100,2) #the best >20%
df['Working capital '] = round((df['Current assets']-df['Short term debt']),0) #the best >0

# %%
#Activities 
df['Days sales outstanding'] = round((df['Short term debt']*365/df['Revenue']),0) #
df['Days inventory'] = round((df['Inventory']*365/df['Revenue']),0) #
df['Payables period'] = round((df['Short term debt']*365/df['Revenue']),0) #
df['Cash conversion cycle'] = round((df['Days sales outstanding']+df['Days inventory']-df['Payables period']),0) #the best <0

# %%
#Liabilities 
df['Longterm Debt/Equity Ratio'] = round((df['Long term debt'] \
                                    /df['Equity'])*100,2) #the best <20%
df['Debt ratio'] = round(((df['Long term debt']+df['Short term debt']) \
                          /df['Total assets'])*100,2) #the best <67%

# %%
#Property 
df['1st degree of coverage'] = round((df['Equity']/df['Fixed assets']),2) #the best >0.6

# %%
#Cash flow
def flow(data):
        if data > 0: return 1
        else: return 0
        
df['Operating cash flow rate']=0        
df['Operating fash flow rate']=df['Operating cash flow'].apply(flow) #the best >0

df['Investing cash flow rate']=0        
df['Investing cash flow rate']=df['Investing cash flow'].apply(flow) #the best <0

df['Finance cash flow rate']=0        
df['Finance cash flow rate']=df['Finance cash flow'].apply(flow) #the best <0

df['Free cash flow rate']=0        
df['Free cash flow rate']=df['Free cash flow'].apply(flow) #the best >0

# %%
#Cash flow description

def flows(data):
        if ((data['Operating cash flow rate'] > 0) & \
        (data['Investing cash flow rate'] > 0) & \
        (data['Finance cash flow rate'] > 0)) : return 'I - (+++) rare situation, need to analyze cases'      
        elif ((data['Operating cash flow rate'] > 0) & \
        (data['Investing cash flow rate']) > 0 & \
        (data['Finance cash flow rate']) == 0): return 'II - (++-) restructuring process'    
        elif ((data['Operating cash flow rate'] > 0) & \
        (data['Investing cash flow rate']) == 0 & \
        (data['Finance cash flow rate']) == 0): return 'III - (+--) stable company, the best'    
        elif ((data['Operating cash flow rate'] == 0) & \
        (data['Investing cash flow rate']) == 0 & \
        (data['Finance cash flow rate']) == 0) : return 'IV - (---) bankrupt'    
        elif ((data['Operating cash flow rate'] < 0) & \
        (data['Investing cash flow rate']) > 0 & \
        (data['Finance cash flow rate']) > 0)  : return 'V - (-++) temporary problems'    
        elif ((data['Operating cash flow rate'] == 0) & \
        (data['Investing cash flow rate']) == 0 & \
        (data['Finance cash flow rate']) > 0)  : return 'VI - (--+) start-up, early stage of activity'    
        elif ((data['Operating cash flow rate'] == 0) & \
        (data['Investing cash flow rate']) > 0 & \
        (data['Finance cash flow rate']) == 0)   : return 'VII - (-+-) probable bankruptcy'    
        elif ((data['Operating cash flow rate'] > 0) & \
        (data['Investing cash flow rate']) == 0 & \
        (data['Finance cash flow rate']) == 0)  : return 'VIII - (+-+) after the start-up phase'                                 
        else: return 'Error'

df['Cash flow description']='0'      
df['Cash flow description']=df.apply(flows, axis=1)

# %%
df[['Year','Cash flow description']]
# Out:
#    Year                 Cash flow description
# 1  2012  III - (+--) stable company, the best
# 2  2013  III - (+--) stable company, the best
# 3  2014  III - (+--) stable company, the best
# 4  2015  III - (+--) stable company, the best
# 5  2016  III - (+--) stable company, the best
# 6  2017  III - (+--) stable company, the best
# 7  2018  III - (+--) stable company, the best
# 8  2019  III - (+--) stable company, the best
# 9  2020  III - (+--) stable company, the best

# %%
df[['Dividend rate','Dividend','Change in book value %','Change in revenues %','Change in net income %']]
# Out:
#    Dividend rate  Dividend  Change in book value %  Change in revenues %  \
# 1            0.0       0.0                     NaN                   NaN
# 2            0.0    1459.0                   149.0                 104.0
# 3            2.1    6000.0                    53.0                  69.0
# 4            2.4    9527.0                    84.0                  74.0
# 5            2.3   18283.0                    50.0                  60.0
# 6            2.5   27810.0                    51.0                  44.0
# 7            1.0   47638.0                     1.0                  17.0
# 8            2.1   48153.0                    20.0                  22.0
# 9            1.4   50213.0                    19.0                  14.0
#
#    Change in net income %
# 1                     NaN
# 2                   136.0
# 3                    71.0
# 4                    91.0
# 5                    51.0
# 6                    53.0
# 7                    13.0
# 8                    19.0
# 9                     8.0

# %% [markdown]
# ## The rating of the company

# %%
#Score based on fundamental indicators

def punkty(dane):
    l=0
    
    #Dywidenda
    if (dane['Stopa dywidendy'] > 2): l=l+1;
    if (dane['Wartość dywidendy na akcje'] > 1): l=l+1;
        
    #Wartość księgowa
    if (dane['Zmiana wartości księgowej %'] > 0): l=l+1;
    #Wzrastanie przychodów ze sprzedaży
    if (dane['Zmiana przychodów ze sprzedaży %'] > 0): l=l+1;
    #Wzrastanie zysku netto
    if (dane['Zmiana zysku netto %'] > 0): l=l+1;
        
    #Rentowność
    if (dane['ROE %'] > 20): l=l+1;
    if (dane['ROA %'] > 10): l=l+1;
    if (dane['ROS %'] > 10): l=l+1;
    if (dane['Rentowność operacyjna %'] > 10): l=l+1;
    if (dane['Rentowność zysku netto %'] > 10): l=l+1;
    #Płynność    
    if (dane['Płynność bieżąca'] > 2): l=l+1;
    if (dane['Płynność gotówkowa %'] > 20): l=l+1;
    if (dane['Kapital obrotowy'] > 0): l=l+1;
    #Aktywności    
    if (dane['Cykl konwersji gotówki'] < 0): l=l+1;
    #Zadłużenie  
    if (dane['Zadłużenie długoterminowe kapitału własnego'] < 20): l=l+1;
    if (dane['Wskaźnik ogólnego zadłużenia'] < 67): l=l+1;
        
    #Przepływy pieniężne opis
    if (dane['Przepływy pieniężne opis'] == 'III - (+--) stabilna spółka, najlepsza sytuacja'): l=l+1    
    elif (dane['Przepływy pieniężne opis'] == 'VI - (--+) start-up, wczesna faza dzialalności'): l=l+1
    elif (dane['Przepływy pieniężne opis'] == 'VIII - (+-+) po fazie start-up'): l=l+1;
    #Majątkowe
    if (dane['I stopień pokrycia'] > 0.6): l=l+1;
        
    return l
        
df['Punkty']='0'      
df['Punkty']=df.apply(punkty, axis=1)

# %% [markdown]
# Ocena:
# - 15-18: Bardzo dobra spółka
# - 12-14: Dobra spółka
# - 9-11: Śrenia spółka
# - 0-9: Słaba spółka

# %%
#Ostateczna ocena

def ocena(punkt):
    if (punkt >= 15): return ('Bardzo dobra spółka')
    elif (punkt >= 12): return ('Dobra spółka')
    elif (punkt >= 9): return ('Średnia spółka')
    else: return ('Słaba spółka')

df['Ocena'] = df['Punkty'].apply(ocena)

# %%
df[['Lata','Punkty', 'Ocena']]
# Out:
#    Lata  Punkty                Ocena
# 1  2012      15  Bardzo dobra spółka
# 2  2013      16  Bardzo dobra spółka
# 3  2014      16  Bardzo dobra spółka
# 4  2015      16  Bardzo dobra spółka
# 5  2016      17  Bardzo dobra spółka
# 6  2017      17  Bardzo dobra spółka
# 7  2018      16  Bardzo dobra spółka
# 8  2019      17  Bardzo dobra spółka
# 9  2020      16  Bardzo dobra spółka

# %% [markdown]
# ## Wykres wskaźników

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Lata', y='Punkty', 
                  data=df, 
                  color='Black', 
                  label = 'Ocena punktowa spółki:\n\
15-18: Bardzo dobra spółka\n\
12-14: Dobra spółka\n\
9-11: Śrenia spółka\n\
0-9: Słaba spółka')

ax.set_title('Wykres oceny punktowej spółki');
plt.xlabel('Lata')
plt.ylabel('Wartość')
plt.legend(frameon=False)

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Lata', y='Zmiana przychodów ze sprzedaży %', 
                  data=df, 
                  color='lightgray', 
                  label = 'Zmiana przychodów ze sprzedaży %')
ax = sns.lineplot(x='Lata', y='Zmiana zysku netto %', 
                  data=df, 
                  color='darkgray', 
                  label = 'Zmiana zysku netto %')
ax = sns.lineplot(x='Lata', y='Zmiana wartości księgowej %', 
                  data=df, 
                  color='gray', 
                  label = 'Zmiana wartości księgowej %')
ax.set_title('Wykres zmiany przychodów i zysku');
plt.xlabel('Lata')
plt.ylabel('Wartość')
plt.legend(frameon=False)

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Lata', y='Stopa dywidendy', 
                  data=df, 
                  color='lightgray',
                  label = 'Stopa dywidendy %')
ax = sns.lineplot(x='Lata', y='Wartość dywidendy na akcje', 
                  data=df, 
                  color='gray',
                  label = 'Wartość dywidendy na akcje')

ax.set_title('Wykres zmiany dywidendy');
plt.xlabel('Lata')
plt.ylabel('Wartość')
plt.legend(frameon=False)

# %%
"""
#do wykorzystania
def rule(x, y):
    if x == 'high' and y > 10:
         return 1
    else:
         return 0
df = pd.DataFrame({ 'c1':[ 'high' ,'high', 'low', 'low'], 'c2': [0, 23, 17, 4]})
df['new'] = df.apply(lambda x: rule(x['c1'], x['c2']), axis =  1)
df.head()
"""
# Out:
# "\n#do wykorzystania\ndef rule(x, y):\n    if x == 'high' and y > 10:\n         return 1\n    else:\n         return 0\ndf = pd.DataFrame({ 'c1':[ 'high' ,'high', 'low', 'low'], 'c2': [0, 23, 17, 4]})\ndf['new'] = df.apply(lambda x: rule(x['c1'], x['c2']), axis =  1)\ndf.head()\n"
